# %%
import csv

# %%
with open('./_assets/graphs/data1.csv', newline='', encoding='utf-8') as f:
        data = csv.reader(f, delimiter=',', quotechar='|')
        for row in data:
            print(row)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [15], line 3
#       1 with open('./_assets/graphs/data1.csv', newline='', encoding='utf-8') as csvfile:
#       2         data = csv.reader(csvfile, delimiter=',', quotechar='|')
# ----> 3         print(data())
#       4         for row in data:
#       5             print(row)
#
# TypeError: '_csv.reader' object is not callable

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 for row in data:
#       2     print(row)
#
# ValueError: I/O operation on closed file.
